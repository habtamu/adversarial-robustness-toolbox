# %% [markdown]
# ### Azure Machine Learning Service Framework

# %% [markdown]
# #### Set up Development Environment

# %% [markdown]
# Initialize Workspace
# - Import base Azure ML packages
# - Check the SDK version
# - Connect to the workspace

# %% [markdown]
# #### Set up: Initialize the Workspace

# %%
# base packages to work with AMLS
import azureml.core
from azureml.core import Workspace

# check core SDK version number
print("Ready to use Azure ML", azureml.core.VERSION)
# Out:
# Ready to use Azure ML 1.18.0

# %%
SUBSCRIPTION_ID='79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5' # provide your subscription ID
RESOURCE_GROUP_NAME  = 'unive-resource-group' # provide a resource group name
WORKSPACE_NAME  = 'unive-workspace' # provide a name for your workspace
REGION = 'westeurope' # For example: 'westeurope' or 'eastus2' or 'westus2' or 'southeastasia'.

ws = None
try:
    # Find existing workspace
    ws = Workspace(workspace_name=WORKSPACE_NAME,
                   subscription_id=SUBSCRIPTION_ID,
                   resource_group= RESOURCE_GROUP_NAME)
    print (ws.name, "found.")
except Exception as ex:
    # If workspace not found, create it
    print(ex.message)
    print("Attempting to create new workspace...")
    ws = Workspace.create(name=WORKSPACE_NAME, 
                          subscription_id=SUBSCRIPTION_ID,
                          resource_group=RESOURCE_GROUP_NAME,
                          create_resource_group=True,
                          location=REGION)
    print(ws.name, "created.")
finally:
    # Save the workspace configuration for later
    if ws != None:
        # write out the workspace details to a configuration file: .azureml/config.json
        ws.write_config(path='.azureml')
        print(ws.name, "saved.")

# %%
# load workspace configuration from the config.json file in the current folder.
ws = Workspace.from_config()
print(ws.name, ws.location, ws.resource_group, ws.location, sep='\t')
# Out:
# unive-workspace	westeurope	unive-resource-group	westeurope

# %% [markdown]
# #### Set up: create compute

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

ws = Workspace.from_config() # This automatically looks for a directory .azureml
CPU_CLUSTER_NAME = "cpu-cluster" # Choose a name for your CPU cluster

# Verify that the cluster does not exist already
try:
    cpu_cluster = ComputeTarget(workspace=ws, name=CPU_CLUSTER_NAME)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_D1_v2',
                                                            min_nodes = 1,
                                                            max_nodes=2, #will autoscale between zero and two nodes
                                                            idle_seconds_before_scaledown=300)
    cpu_cluster = ComputeTarget.create(ws, CPU_CLUSTER_NAME, compute_config)

cpu_cluster.wait_for_completion(show_output=True)

# %% [markdown]
# #### Set up: upload data to datastore

# %%
# Get the default datastore
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name) # workspaceblobstore <- Default

# Adult Census Income Binary classfication dataset
default_ds.upload_files(files=['./data/adult_transformed.csv'], # Upload the data/adults.csv file
                       target_path='adults-data/', # Put it in a folder path in the datastore
                       overwrite=True, # Replace existing files of the same name
                       show_progress=True)
# Out:
# azureml_globaldatasets - Default = False
# workspaceblobstore - Default = True
# workspacefilestore - Default = False
# Uploading an estimated of 1 files
# Uploading ./data/adult_transformed.csv
# Uploaded ./data/adult_transformed.csv, 1 files out of an estimated total of 1
# Uploaded 1 files
# $AZUREML_DATAREFERENCE_1963e0e7b34f4f61bc5969901ceaf9b2

# %% [markdown]
# #### Initialize an Experiment

# %%
# Name your experiment here.
experiment_name = 'experiment-1-adult-DecisionForest_Bagging'

from azureml.core import Experiment
experiment = Experiment(workspace=ws, name=experiment_name)
print(f"Experiment: {experiment.name}")
# Out:
# Experiment: experiment-1-adult-DecisionForest_Bagging

# %%
# Directory to write training script.
# Code Directory
import os
script_folder = os.path.join(os.getcwd(), "script")
os.makedirs(script_folder, exist_ok=True)

# %% [markdown]
# #### Dataset
#
# This is also the folder where we’ll want to write out any file outputs (training, scoring, YAML,etc.)

# %%
from azureml.core import Dataset

ds = ws.get_default_datastore()
print(ds.datastore_type, ds.account_name, ds.container_name)

#Create a tabular dataset from the path on the datastore (this may take a short while)
data_set = Dataset.Tabular.from_delimited_files(path=(ds, 'adults-data/adult_transformed.csv'))

# Display the first 20 rows as a Pandas dataframe
data_set.take(4).to_pandas_dataframe()
# Out:
# AzureBlob univeworstorage4bcd40317 azureml-blobstore-d5af5167-804c-41a6-bae2-8631f76e6de9
#    age  fnlwgt  education  education-num  marital-status  relationship  race  \
# 0   39   77516          9             13               4             1     4
# 1   50   83311          9             13               2             0     4
# 2   38  215646         11              9               0             1     4
# 3   53  234721          1              7               2             0     2
#
#    sex  capital-gain  capital-loss  hours-per-week  income
# 0    1          2174             0              40       0
# 1    1             0             0              13       0
# 2    1             0             0              40       0
# 3    1             0             0              40       0

# %%
# Register the dataset
dataset_name = 'Dataset-adults-processed'
data_set = data_set.register(workspace=ws, 
                           name=dataset_name,
                           description='UCI Adult Dataset (1994 Census)-Transformed',
                           tags = {'year':'1994', 'category':'Census Income'},
                           create_new_version=True)

# List the datasets registered in the workspace
for ds in ws.datasets:
    print(ds)
# Out:
# Dataset-adults-processed
# Dataset-adults-transformed
# Dataset-adults

# %% [markdown]
# #### Setup: create a python environment

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies

# Create a Python environment
adults_env = Environment("adults-env")
#adults_env.python.user_managed_dependencies = False # we're going to create a custom environment
adults_env.docker.enabled = True # we use a docker container (default is true)

# Create a set of package dependencies (conda or pip as required)
adults_conda = CondaDependencies.create(conda_packages=['pandas','numpy','scikit-learn','joblib','ipykernel','matplotlib','lightgbm'],
                                          pip_packages=['azureml-sdk','argparse','pyarrow','mlxtend'])


# Add the dependencies to the environment
adults_env.python.conda_dependencies = adults_conda
adults_env.python.conda_dependencies.save_to_file(".", "adults-env.yml")
adults_env.register(workspace=ws)

print(f"List of existing environments:" )
for name,env in ws.environments.items():
    print("Name {} \t version {}".format(name,env.version))

# %% [markdown]
# #### Training the model
#
# Three steps involved in training and executing an experiment in the Azure ML Service:
#
# 1. Create the Training Script
#
# For this code to work inside of the Azure ML service, the last few lines that output the pickle file are mandatory. The pickle file is what is used to register the Model inside of the Azure ML service.

# %%
# %%writefile $script_folder/train_adult_DecisionForest_Bagging.py
import os
import argparse
import joblib
import pickle
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from azureml.core import Workspace, Dataset, Experiment, Run

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

parser = argparse.ArgumentParser()
parser.add_argument('--data-folder', type=str, dest='data_folder', help='data folder mounting point')
parser.add_argument('--regularization', type=float, dest='reg', default=0.01, help='regularization rate')
args = parser.parse_args()

# Get the experiment run context
run = Run.get_context()

# load the diabetes dataset
dataset_name = 'Dataset-adults-processed'
print("Loading data from " + dataset_name)
#Adult Census Income Binary classfication dataset
df = Dataset.get_by_name(workspace=run.experiment.workspace, name=dataset_name).to_pandas_dataframe()
X = df.drop('income', axis=1).values
y = df['income'].values

#use stratify for un balanced number of examples for each class label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42,shuffle=True)

print(f'X_train.shape: {X_train.shape}')
print(f'y_train.shape: {y_train.shape}')
print(f'X_test.shape: {X_test.shape}')
print(f'y_test.shape: {y_test.shape}')
    
# Model Training: DecisionTreeClassifier + BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier

tree  = DecisionTreeClassifier(criterion='entropy', max_depth=32, min_samples_leaf=1, random_state=42)

model = BaggingClassifier(base_estimator=tree,
                        n_estimators=10,
                        oob_score=True,
                        bootstrap=True,
                        bootstrap_features=False,
                        n_jobs=1,
                        random_state=42)

model.fit(X_train, y_train)
print(f'model: {model}')
print("OOB Accuracy: %0.2f" % model.oob_score_)
print("Test Accuracy: %0.2f" % model.score(X_test, y_test))

# Evaluate the model
from sklearn import metrics

# using threshold
threshold = 0.5 # set threshold as 0.5
y_pred = (model.predict_proba(X_test)[:,1] >= threshold).astype(int) 
print(f"y_pred: {y_pred}")
run.log('y_pred:', y_pred)

print(f'Misclassified examples:{(y_test != y_pred).sum()}')
run.log('Misclassified examples:', (y_test != y_pred).sum())

# Confusion Matrix
# The confusion matrix of our model over the Iris dataset is shown as follows:
conf_mat = metrics.confusion_matrix(y_test, y_pred)
print(f"confusion matrix:\n {conf_mat}")
run.log('confusion matrix:', conf_mat)

# AUC
auc = metrics.roc_auc_score(y_test, y_pred)
print(f"auc: {auc}")
run.log('auc:', auc)

# Accuracy
accuracy = metrics.accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}") 
run.log('Accuracy:', accuracy)

# Precision
precision = metrics.precision_score(y_test, y_pred)
print(f"Precision: {precision}")
run.log('Precision:', precision )

# Recall
recall = metrics.recall_score(y_test, y_pred)
print(f"Recall: {recall}")
run.log('Recall:', recall)

# F1
f1 = metrics.f1_score(y_test, y_pred)
print(f"F1: {f1}")
run.log('F1:', f1)

# classification_report
print('classification_report')
print(metrics.classification_report(y_test, y_pred))
run.log('classification_report', metrics.classification_report(y_test, y_pred))

# Save model
print('Exported model: adult_DecisionForest_Bagging.pkl')
f = open('adult_DecisionForest_Bagging.pkl', 'wb')
pickle.dump(model, f)
f.close()

os.makedirs('outputs', exist_ok=True)
# note file saved in the outputs folder is automatically uploaded into experiment record
joblib.dump(value=model, filename='outputs/adult_DecisionForest_Bagging.pkl')

# save Graphs
# Graph 1
fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(conf_mat, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_mat.shape[0]):
    for j in range(conf_mat.shape[1]):
        ax.text(x=j, y=i, s=conf_mat[i, j], va='center', ha='center')

plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.tight_layout()
run.log_image('conf_mat', plot=plt)
# Out:
# Overwriting /mnt/batch/tasks/shared/LS_root/mounts/clusters/cpu-compute-ds1v2/code/Users/877159/script/train_adult_DecisionForest_Bagging.py

# %% [markdown]
# 2. Submit the Training Job to the Compute Cluster
#
# When this code section completes, an Experiment will show up in the Azure portal in your Azure ML workspace resource. Also, assuming your Experiment has a pickle file output, that file is created here.

# %%
from azureml.core.compute import AmlCompute
from azureml.core import ScriptRunConfig
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# Create a script config
src = ScriptRunConfig(source_directory=script_folder, script='train_adult_DecisionForest_Bagging.py')

compute_target = None
for compute_name  in ws.compute_targets:
    compute_target = ws.compute_targets[compute_name]
    if compute_target and type(compute_target) is AmlCompute:
        print("found compute target: " + compute_name)
# Set compute target to the one created in previous step
src.run_config.target = compute_target
print(f"compute_target: {compute_target}")

# Set environment
adults_env = ws.environments["adults-env"] 
src.run_config.environment = adults_env
 
run = experiment.submit(config=src)
run
# Out:
# found compute target: cpu-cluster
# compute_target: AmlCompute(workspace=Workspace.create(name='unive-workspace', subscription_id='79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5', resource_group='unive-resource-group'), name=cpu-cluster, id=/subscriptions/79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5/resourceGroups/unive-resource-group/providers/Microsoft.MachineLearningServices/workspaces/unive-workspace/computes/cpu-cluster, type=AmlCompute, provisioning_state=Succeeded, location=westeurope, tags=None)
# Run(Experiment: experiment-1-adult-DecisionForest_Bagging,
# Id: experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13,
# Type: azureml.scriptrun,
# Status: Starting)

# %% [markdown]
# And we can watch the execution of the Training with the following code.

# %%
# %%time
# specify show_output to True for a verbose log
run.wait_for_completion(show_output=True)
# Out:
# RunId: experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13
# Web View: https://ml.azure.com/experiments/experiment-1-adult-DecisionForest_Bagging/runs/experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13?wsid=/subscriptions/79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5/resourcegroups/unive-resource-group/workspaces/unive-workspace
#
# Execution Summary
# =================
# RunId: experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13
# Web View: https://ml.azure.com/experiments/experiment-1-adult-DecisionForest_Bagging/runs/experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13?wsid=/subscriptions/79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5/resourcegroups/unive-resource-group/workspaces/unive-workspace
#
# CPU times: user 36.2 ms, sys: 181 µs, total: 36.3 ms
# Wall time: 277 ms
# {'runId': 'experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13',
#  'target': 'cpu-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2020-11-24T01:42:52.911736Z',
#  'endTimeUtc': '2020-11-24T01:43:59.293837Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'd6ce35d2-0710-431e-9c51-2f3c11e22af7',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': '6c2d784d-cabf-43e4-88c1-9d18a1b325c1'}, 'consumptionDetails': {'type': 'Reference'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'train_adult_DecisionForest_Bagging.py',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'cpu-cluster',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'environment': {'name': 'adults-env',
#    'version': '1',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['anaconda', 'conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-sdk~=1.18.0', 'argparse', 'pyarrow', 'mlxtend']},
#       'pandas',
#       'numpy',
#       'scikit-learn',
#       'joblib',
#       'ipykernel',
#       'matplotlib',
#       'lightgbm'],
#      'name': 'azureml_72efb94fba8b2a327b62eea6d5035300'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'frameworkImage': None,
#    'imageVersion': None,
#    'location': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_6e0dfb0e4e67aec697af6ebbbaf4eaf20f50cf5169d280b66b6b7e218cb53b28_d.txt': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/azureml-logs/55_azureml-execution-tvmps_6e0dfb0e4e67aec697af6ebbbaf4eaf20f50cf5169d280b66b6b7e218cb53b28_d.txt?sv=2019-02-02&sr=b&sig=Chz2hP%2BPdEI1NIx1EHiCat2KvhV1nhCvM9WWwJm3fDg%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_6e0dfb0e4e67aec697af6ebbbaf4eaf20f50cf5169d280b66b6b7e218cb53b28_d.txt': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/azureml-logs/65_job_prep-tvmps_6e0dfb0e4e67aec697af6ebbbaf4eaf20f50cf5169d280b66b6b7e218cb53b28_d.txt?sv=2019-02-02&sr=b&sig=p2h19l%2FlWsQdBbKMeKz%2FV6iPsp4FnOJJCByjSFiJEfo%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=D26ukDcS5HkaYjXOf%2Fcdal%2Fz46oF2L9EQrx5PBreX1U%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_6e0dfb0e4e67aec697af6ebbbaf4eaf20f50cf5169d280b66b6b7e218cb53b28_d.txt': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/azureml-logs/75_job_post-tvmps_6e0dfb0e4e67aec697af6ebbbaf4eaf20f50cf5169d280b66b6b7e218cb53b28_d.txt?sv=2019-02-02&sr=b&sig=VhC2UY14JVXx8ZQAPaCTutR%2FS1R4zAhEkuVMszVZI4s%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'azureml-logs/process_info.json': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=KLqoM78CnenwnPLOFx3AjJrrYuypN4rmZwje%2BEVeVxQ%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'azureml-logs/process_status.json': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=1oU2TP0ICTVjl79N3C2b6Wngwz%2F4he4%2FFN2zmSXqkME%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'logs/azureml/100_azureml.log': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/logs/azureml/100_azureml.log?sv=2019-02-02&sr=b&sig=fsMRTr8BGsPjuY5Y6%2BdrSA5cOS4JuUFq9t%2B3f8CS2ts%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/logs/azureml/dataprep/backgroundProcess.log?sv=2019-02-02&sr=b&sig=rB2X3NgrxfZkSVydrHBF8VPDG0d86ry7gySeXNq6ovk%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-02-02&sr=b&sig=uDtTm1hJq%2FC3kE8aJzC7qL%2BkFpjYBv8u9qGZbQh%2FEmw%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'logs/azureml/dataprep/engine_spans_92f6ec4d-30cf-4a71-9d73-95a11a0b8889.jsonl': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/logs/azureml/dataprep/engine_spans_92f6ec4d-30cf-4a71-9d73-95a11a0b8889.jsonl?sv=2019-02-02&sr=b&sig=B8HZOVaSq1ZMsM7XeLSF8E%2FnhTc6PMkNhITrjjBDOS0%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'logs/azureml/dataprep/python_span_92f6ec4d-30cf-4a71-9d73-95a11a0b8889.jsonl': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/logs/azureml/dataprep/python_span_92f6ec4d-30cf-4a71-9d73-95a11a0b8889.jsonl?sv=2019-02-02&sr=b&sig=Qfg92G4pR79RQMkqkYbIT1BLETiJoE7sD%2F9T9lgcIQk%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=oYmAHKOUv2JhEhyvWe%2FnQISerTwLcLtUVzNlK9Bl9MQ%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://univeworstorage4bcd40317.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-DecisionForest_Bagging_1606182110_5bca7b13/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=F69v1b90QMxL11%2BDzepFPjUoB%2FTyi4ueC2pqgQDjAQw%3D&st=2020-11-24T01%3A34%3A53Z&se=2020-11-24T09%3A44%3A53Z&sp=r'}}

# %% [markdown]
# 3. Register the Model
#
# Registers the output pickle file in the Azure ML service workspace. Once this code completes, a Model will show up in the Azure portal.

# %%
# register model 
model = run.register_model(model_name='model-adult', model_path='outputs/adult_DecisionForest_Bagging.pkl')
print(model.name, model.id, model.version, sep='\t')
# Out:
# model-adult	model-adult:4	4

# %% [markdown]
# 4. Download the model

# %%
# download model
import os 
from azureml.core import Workspace
from azureml.core.model import Model

ws = Workspace.from_config()
model=Model(ws, 'model-adult')
model.download(target_dir=os.path.join(os.getcwd(), "model"), exist_ok=True)

# verify the downloaded model file
file_path = os.path.join(os.getcwd(), "model/adult_DecisionForest_Bagging.pkl")
print(f"file path: {file_path}")
os.stat(file_path)
# Out:
# file path: /mnt/batch/tasks/shared/LS_root/mounts/clusters/cpu-compute-ds1v2/code/Users/877159/model/adult_DecisionForest_Bagging.pkl
# os.stat_result(st_mode=33279, st_ino=9511699170029731840, st_dev=46, st_nlink=1, st_uid=0, st_gid=0, st_size=3536575, st_atime=1606182709, st_mtime=1606182709, st_ctime=1606182709)

# %% [markdown]
# ## Azure Notebook

# %%
Loading data from Dataset-adults-processed
X_train.shape: (22792, 11)
y_train.shape: (22792,)
X_test.shape: (9769, 11)
y_test.shape: (9769,)
/azureml-envs/azureml_72efb94fba8b2a327b62eea6d5035300/lib/python3.6/site-packages/sklearn/ensemble/_bagging.py:638: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
  warn("Some inputs do not have OOB scores. "
/azureml-envs/azureml_72efb94fba8b2a327b62eea6d5035300/lib/python3.6/site-packages/sklearn/ensemble/_bagging.py:643: RuntimeWarning: invalid value encountered in true_divide
  predictions.sum(axis=1)[:, np.newaxis])
model: BaggingClassifier(base_estimator=DecisionTreeClassifier(criterion='entropy',
                                                        max_depth=32,
                                                        random_state=42),
                  n_jobs=1, oob_score=True, random_state=42)
OOB Accuracy: 0.83
Test Accuracy: 0.84
y_pred: [0 0 0 ... 0 0 1]
Misclassified examples:1622
confusion matrix:
 [[6687  768]
 [ 854 1460]]
auc: 0.7639619914821687
Accuracy: 0.8339645818405159
Precision: 0.6552962298025135
Recall: 0.6309420916162489
F1: 0.6428885953324527
classification_report
              precision    recall  f1-score   support

           0       0.89      0.90      0.89      7455
           1       0.66      0.63      0.64      2314

    accuracy                           0.83      9769
   macro avg       0.77      0.76      0.77      9769
weighted avg       0.83      0.83      0.83      9769

Exported model: adult_DecisionForest_Bagging.pkl

# %%
from IPython.display import Image

Image(filename='images/Azure/Exp-2/DecisionForest_Bagging/conf_mat.png')

# %%
Image(filename='images/Azure/Exp-2/DecisionForest_Bagging/metrics.png')

# %%
Image(filename='images/Azure/Exp-2/DecisionForest_Bagging/driver_log.png')

# %%
Image(filename='images/Azure/Exp-2/DecisionForest_Bagging/dataset.png')

# %%
Image(filename='images/Azure/Exp-2/DecisionForest_Bagging/Notebook.png')

# %%
Image(filename='images/Azure/Exp-2/DecisionForest_Bagging/Model.png')

# %%
Image(filename='images/Azure/Exp-2/DecisionForest_Bagging/snapshot.png')

# %% [markdown]
# ## 5 Result Analysis

# %%
Image(filename='images/Azure/Exp-2/DecisionForest_Bagging/result.png')
