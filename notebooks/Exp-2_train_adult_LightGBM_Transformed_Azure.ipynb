# %% [markdown]
# ### Azure Machine Learning Service Framework

# %% [markdown]
# #### Set up Development Environment

# %% [markdown]
# Initialize Workspace
# - Import base Azure ML packages
# - Check the SDK version
# - Connect to the workspace

# %% [markdown]
# #### Set up: Initialize the Workspace

# %%
# base packages to work with AMLS
import azureml.core
from azureml.core import Workspace

# check core SDK version number
print("Ready to use Azure ML", azureml.core.VERSION)
# Out:
# Ready to use Azure ML 1.18.0

# %%
SUBSCRIPTION_ID='79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5' # provide your subscription ID
RESOURCE_GROUP_NAME  = 'unive-resource-group' # provide a resource group name
WORKSPACE_NAME  = 'unive-workspace' # provide a name for your workspace
REGION = 'westeurope' # For example: 'westeurope' or 'eastus2' or 'westus2' or 'southeastasia'.

ws = None
try:
    # Find existing workspace
    ws = Workspace(workspace_name=WORKSPACE_NAME,
                   subscription_id=SUBSCRIPTION_ID,
                   resource_group= RESOURCE_GROUP_NAME)
    print (ws.name, "found.")
except Exception as ex:
    # If workspace not found, create it
    print(ex.message)
    print("Attempting to create new workspace...")
    ws = Workspace.create(name=WORKSPACE_NAME, 
                          subscription_id=SUBSCRIPTION_ID,
                          resource_group=RESOURCE_GROUP_NAME,
                          create_resource_group=True,
                          location=REGION)
    print(ws.name, "created.")
finally:
    # Save the workspace configuration for later
    if ws != None:
        # write out the workspace details to a configuration file: .azureml/config.json
        ws.write_config(path='.azureml')
        print(ws.name, "saved.")
# Out:
# get_workspace error using subscription_id=79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5, resource_group_name=unive-resource-group, workspace_name=unive-workspace
# Workspace not found.
# Attempting to create new workspace...
# UserWarning: The resource group doesn't exist or was not provided. AzureML SDK is creating a resource group=unive-resource-group in location=westeurope using subscription=79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5.
# Deploying AppInsights with name univeworinsightse53aa460.
# Deployed AppInsights with name univeworinsightse53aa460. Took 3.87 seconds.
# Deploying KeyVault with name univeworkeyvault7562bca7.
# Deploying StorageAccount with name univeworstoraged97f3a4a3.
# Deployed KeyVault with name univeworkeyvault7562bca7. Took 19.05 seconds.
# Deployed StorageAccount with name univeworstoraged97f3a4a3. Took 22.22 seconds.
# Deploying Workspace with name unive-workspace.
# Deployed Workspace with name unive-workspace. Took 20.56 seconds.
# unive-workspace created.
# unive-workspace saved.

# %%
# load workspace configuration from the config.json file in the current folder.
ws = Workspace.from_config()
print(ws.name, ws.location, ws.resource_group, ws.location, sep='\t')
# Out:
# unive-workspace	westeurope	unive-resource-group	westeurope

# %% [markdown]
# #### Set up: create compute

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

ws = Workspace.from_config() # This automatically looks for a directory .azureml
CPU_CLUSTER_NAME = "cpu-cluster" # Choose a name for your CPU cluster

# Verify that the cluster does not exist already
try:
    cpu_cluster = ComputeTarget(workspace=ws, name=CPU_CLUSTER_NAME)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_D1_v2',
                                                            max_nodes=2, #will autoscale between zero and two nodes
                                                            idle_seconds_before_scaledown=300)
    cpu_cluster = ComputeTarget.create(ws, CPU_CLUSTER_NAME, compute_config)

cpu_cluster.wait_for_completion(show_output=True)
# Out:
# Creating
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# #### Set up: upload data to datastore

# %%
# Get the default datastore
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name) # workspaceblobstore <- Default

# Adult Census Income Binary classfication dataset
default_ds.upload_files(files=['./data/adult_transformed.csv'], # Upload the data/adults.csv file
                       target_path='adults-data/', # Put it in a folder path in the datastore
                       overwrite=True, # Replace existing files of the same name
                       show_progress=True)
# Out:
# azureml_globaldatasets - Default = False
# workspacefilestore - Default = False
# workspaceblobstore - Default = True
# Uploading an estimated of 1 files
# Uploading ./data/adult_transformed.csv
# Uploaded ./data/adult_transformed.csv, 1 files out of an estimated total of 1
# Uploaded 1 files
# $AZUREML_DATAREFERENCE_4c25eef38d3d41f5b5647295d6cc7c13

# %% [markdown]
# #### Initialize an Experiment

# %%
# Name your experiment here.
experiment_name = 'experiment-1-adult-LightGBM'

from azureml.core import Experiment
experiment = Experiment(workspace=ws, name=experiment_name)
print(f"Experiment: {experiment.name}")
# Out:
# Experiment: experiment-1-adult-LightGBM

# %%
# Directory to write training script.
# Code Directory
import os
script_folder = os.path.join(os.getcwd(), "script")
os.makedirs(script_folder, exist_ok=True)

# %% [markdown]
# #### Dataset
#
# This is also the folder where we’ll want to write out any file outputs (training, scoring, YAML,etc.)

# %%
from azureml.core import Dataset

ds = ws.get_default_datastore()
print(ds.datastore_type, ds.account_name, ds.container_name)

#Create a tabular dataset from the path on the datastore (this may take a short while)
data_set = Dataset.Tabular.from_delimited_files(path=(ds, 'adults-data/adult_transformed.csv'))

# Display the first 20 rows as a Pandas dataframe
data_set.take(4).to_pandas_dataframe()
# Out:
# AzureBlob univeworstoraged97f3a4a3 azureml-blobstore-4fa98200-a8a5-4724-8330-795635543b23
#    age  fnlwgt  education  education-num  marital-status  relationship  race  \
# 0   39   77516          9             13               4             1     4
# 1   50   83311          9             13               2             0     4
# 2   38  215646         11              9               0             1     4
# 3   53  234721          1              7               2             0     2
#
#    sex  capital-gain  capital-loss  hours-per-week  income
# 0    1          2174             0              40       0
# 1    1             0             0              13       0
# 2    1             0             0              40       0
# 3    1             0             0              40       0

# %%
# Register the dataset
dataset_name = 'Dataset-adults-Transformed'
data_set = data_set.register(workspace=ws, 
                           name=dataset_name,
                           description='UCI Adult Dataset (1994 Census)-Transformed',
                           tags = {'year':'1994', 'category':'Census Income'},
                           create_new_version=True)

# List the datasets registered in the workspace
for ds in ws.datasets:
    print(ds)
# Out:
# Dataset-adults-Transformed
# adults-test-set
# adults-train-set
# Dataset-adults

# %% [markdown]
# #### Setup: create a python environment

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies

# Create a Python environment
adults_env = Environment("adults-env")
#adults_env.python.user_managed_dependencies = False # we're going to create a custom environment
adults_env.docker.enabled = True # we use a docker container (default is true)

# Create a set of package dependencies (conda or pip as required)
adults_conda = CondaDependencies.create(conda_packages=['pandas','numpy','scikit-learn','joblib','ipykernel','matplotlib','lightgbm'],
                                          pip_packages=['azureml-sdk','argparse','pyarrow','mlxtend','watermark'])


# Add the dependencies to the environment
adults_env.python.conda_dependencies = adults_conda
adults_env.python.conda_dependencies.save_to_file(".", "adults-env.yml")
adults_env.register(workspace=ws)

print(f"List of existing environments:" )
for name,env in ws.environments.items():
    print("Name {} \t version {}".format(name,env.version))
# Out:
# List of existing environments:
# Name adults-env 	 version 1
# Name AzureML-AutoML 	 version 48
# Name AzureML-PyTorch-1.0-GPU 	 version 43
# Name AzureML-Scikit-learn-0.20.3 	 version 42
# Name AzureML-TensorFlow-1.12-CPU 	 version 41
# Name AzureML-PyTorch-1.2-GPU 	 version 43
# Name AzureML-TensorFlow-2.0-GPU 	 version 41
# Name AzureML-TensorFlow-2.0-CPU 	 version 40
# Name AzureML-Chainer-5.1.0-GPU 	 version 43
# Name AzureML-TensorFlow-1.13-CPU 	 version 42
# Name AzureML-Minimal 	 version 43
# Name AzureML-Chainer-5.1.0-CPU 	 version 42
# Name AzureML-PyTorch-1.4-GPU 	 version 33
# Name AzureML-PySpark-MmlSpark-0.15 	 version 38
# Name AzureML-PyTorch-1.3-CPU 	 version 38
# Name AzureML-PyTorch-1.1-GPU 	 version 43
# Name AzureML-TensorFlow-1.10-GPU 	 version 43
# Name AzureML-PyTorch-1.2-CPU 	 version 42
# Name AzureML-TensorFlow-1.13-GPU 	 version 43
# Name AzureML-TensorFlow-1.10-CPU 	 version 42
# Name AzureML-PyTorch-1.3-GPU 	 version 40
# Name AzureML-PyTorch-1.4-CPU 	 version 33
# Name AzureML-Tutorial 	 version 59
# Name AzureML-PyTorch-1.0-CPU 	 version 42
# Name AzureML-PyTorch-1.1-CPU 	 version 42
# Name AzureML-TensorFlow-1.12-GPU 	 version 43
# Name AzureML-Designer-VowpalWabbit 	 version 10
# Name AzureML-TensorFlow-2.2-GPU 	 version 10
# Name AzureML-TensorFlow-2.2-CPU 	 version 10
# Name AzureML-PyTorch-1.6-CPU 	 version 10
# Name AzureML-PyTorch-1.6-GPU 	 version 10
# Name AzureML-Triton 	 version 7
# Name AzureML-TensorFlow-2.3-CPU 	 version 5
# Name AzureML-TensorFlow-2.3-GPU 	 version 4
# Name AzureML-DeepSpeed-0.3-GPU 	 version 1
# Name AzureML-Sidecar 	 version 18
# Name AzureML-Dask-CPU 	 version 28
# Name AzureML-Dask-GPU 	 version 26
# Name AzureML-TensorFlow-2.1-GPU 	 version 18
# Name AzureML-PyTorch-1.5-GPU 	 version 24
# Name AzureML-PyTorch-1.5-CPU 	 version 23
# Name AzureML-TensorFlow-2.1-CPU 	 version 17
# Name AzureML-AutoML-DNN-Vision-GPU 	 version 27
# Name AzureML-Hyperdrive-ForecastDNN 	 version 44
# Name AzureML-AutoML-DNN 	 version 46
# Name AzureML-VowpalWabbit-8.8.0 	 version 31
# Name AzureML-AutoML-DNN-GPU 	 version 36
# Name AzureML-AutoML-GPU 	 version 36
# Name AzureML-Designer-Score 	 version 12
# Name AzureML-Designer-PyTorch-Train 	 version 11
# Name AzureML-Designer-IO 	 version 22
# Name AzureML-Designer-Transform 	 version 22
# Name AzureML-Designer-Recommender 	 version 24
# Name AzureML-Designer-CV 	 version 14
# Name AzureML-Designer-NLP 	 version 14
# Name AzureML-Designer-PyTorch 	 version 15
# Name AzureML-Designer-CV-Transform 	 version 14
# Name AzureML-Designer 	 version 24
# Name AzureML-Designer-R 	 version 24

# %% [markdown]
# #### Training the model
#
# Three steps involved in training and executing an experiment in the Azure ML Service:
#
# 1. Create the Training Script
#
# For this code to work inside of the Azure ML service, the last few lines that output the pickle file are mandatory. The pickle file is what is used to register the Model inside of the Azure ML service.

# %%
# %%writefile $script_folder/train_adult_LightGBM.py
import os
import argparse
import joblib
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from azureml.core import Workspace, Dataset, Experiment, Run

parser = argparse.ArgumentParser()
parser.add_argument('--data-folder', type=str, dest='data_folder', help='data folder mounting point')
parser.add_argument('--regularization', type=float, dest='reg', default=0.01, help='regularization rate')
args = parser.parse_args()

# Get the experiment run context
run = Run.get_context()

# load the diabetes dataset
dataset_name = 'Dataset-adults-Transformed'
print("Loading data from " + dataset_name)

#Adult Census Income Binary classfication dataset
df = Dataset.get_by_name(workspace=run.experiment.workspace, name=dataset_name).to_pandas_dataframe()
X = df.drop('income', axis=1).values
y = df['income'].values

#use stratify for un balanced number of examples for each class label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42,shuffle=True)
print(f'X_train.shape: {X_train.shape}')
print(f'y_train.shape: {y_train.shape}')
print(f'X_test.shape: {X_test.shape}')
print(f'y_test.shape: {y_test.shape}')
    
# Model Training: lightgbm
import lightgbm as lgb

d_train = lgb.Dataset(X_train, label=y_train)
params = {}
params['num_leaves'] = 20               # number of leaves for one tree
params['min_data_in_leaf'] = 10         # minimal number data for one leaf, use this to deal with over-fit 
params['learning_rate'] = 0.2           # shrinkage rate
params['num_trees'] = 100               # number of trees(iterations)
params['objective'] = 'binary'          # binary , binary classification task
params['boosting_type'] = 'gbdt'        # boosting type, support gbdt for now, alias: boosting, boost
params['metric'] = 'binary_logloss,auc' # auc 
                                        # binary_logloss , default metric for binary
params['seed'] = 42

# data is ready to train
model = lgb.train(params, d_train)
print(f'model: {model}')

# Evaluate the model
from sklearn import metrics

def convert_prob_to_binary(y_pred):
    # convert probabilities to binary prediction using threshold=0.5
    for i in range(0, y_pred.shape[0]):
        if y_pred[i] >= .5: # setting threshold to .5
            y_pred[i] = 1
        else:
            y_pred[i] = 0
    
    return y_pred

# Prediction
y_pred = model.predict(X_test)
print(f"prediction: {y_pred}")
run.log('y_pred:', y_pred)
print(f'Misclassified examples:{(y_test != y_pred).sum()}')
run.log('Misclassified examples:', (y_test != y_pred).sum())
y_pred = convert_prob_to_binary(y_pred)
        
# Confusion Matrix
conf_mat = metrics.confusion_matrix(y_test, y_pred)
print(f"confusion matrix:\n {conf_mat}")
run.log('confusion matrix:', conf_mat)

# AUC
auc = metrics.roc_auc_score(y_test, y_pred)
print(f"auc: {auc}")
run.log('auc:', auc)

# Accuracy
accuracy = metrics.accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}") 
run.log('Accuracy:', accuracy)

# Precision
precision = metrics.precision_score(y_test, y_pred, average='macro')
print(f"Precision: {precision}")
run.log('Precision:', precision )

# Recall
recall = metrics.recall_score(y_test, y_pred, average='macro')
print(f"Recall: {recall}")
run.log('Recall:', recall)

# F1
f1 = metrics.f1_score(y_test, y_pred, average='macro')
print(f"F1: {f1}")
run.log('F1:', f1)

# classification_report
print('classification_report:')
print(metrics.classification_report(y_test, y_pred))
run.log('classification_report', metrics.classification_report(y_test, y_pred))

# Save model
print('Exported model: adult_transformed_LightGBM.pkl')
f = open('adult_transformed_LightGBM.pkl', 'wb')
pickle.dump(model, f)
f.close()

os.makedirs('outputs', exist_ok=True)
# note file saved in the outputs folder is automatically uploaded into experiment record
joblib.dump(value=model, filename='outputs/adult_transformed_LightGBM.pkl')

#Fig
fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(conf_mat, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_mat.shape[0]):
    for j in range(conf_mat.shape[1]):
        ax.text(x=j, y=i, s=conf_mat[i, j], va='center', ha='center')

plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.tight_layout()

run.log_image('conf_mat', plot=plt)
# Out:
# Writing /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-standardds1-v2/code/Users/877159/script/train_adult_LightGBM.py

# %% [markdown]
# 2. Submit the Training Job to the Compute Cluster
#
# When this code section completes, an Experiment will show up in the Azure portal in your Azure ML workspace resource. Also, assuming your Experiment has a pickle file output, that file is created here.

# %%
from azureml.core.compute import AmlCompute
from azureml.core import ScriptRunConfig
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# Create a script config
src = ScriptRunConfig(source_directory=script_folder, script='train_adult_LightGBM.py')

compute_target = None
for compute_name  in ws.compute_targets:
    compute_target = ws.compute_targets[compute_name]
    if compute_target and type(compute_target) is AmlCompute:
        print("found compute target: " + compute_name)
# Set compute target to the one created in previous step
src.run_config.target = compute_target
print(f"compute_target: {compute_target}")

# Set environment
adults_env = ws.environments["adults-env"] 
src.run_config.environment = adults_env
 
run = experiment.submit(config=src)
run
# Out:
# found compute target: cpu-cluster
# compute_target: AmlCompute(workspace=Workspace.create(name='unive-workspace', subscription_id='79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5', resource_group='unive-resource-group'), name=cpu-cluster, id=/subscriptions/79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5/resourceGroups/unive-resource-group/providers/Microsoft.MachineLearningServices/workspaces/unive-workspace/computes/cpu-cluster, type=AmlCompute, provisioning_state=Succeeded, location=westeurope, tags=None)
# Run(Experiment: experiment-1-adult-LightGBM,
# Id: experiment-1-adult-LightGBM_1605906446_89132a01,
# Type: azureml.scriptrun,
# Status: Starting)

# %%
print("Loading data from " + dataset_name)
#Adult Census Income Binary classfication dataset
data = Dataset.get_by_name(workspace=run.experiment.workspace, name=dataset_name).to_pandas_dataframe()
print(data.shape)
data.tail()
# Out:
# Loading data from Dataset-adults-Transformed
# (32561, 12)
#        age  fnlwgt  education  education-num  marital-status  relationship  \
# 32556   27  257302          7             12               2             5
# 32557   40  154374         11              9               2             0
# 32558   58  151910         11              9               6             4
# 32559   22  201490         11              9               4             3
# 32560   52  287927         11              9               2             5
#
#        race  sex  capital-gain  capital-loss  hours-per-week  income
# 32556     4    0             0             0              38       0
# 32557     4    1             0             0              40       1
# 32558     4    0             0             0              40       0
# 32559     4    1             0             0              20       0
# 32560     4    0         15024             0              40       1

# %% [markdown]
# And we can watch the execution of the Training with the following code.

# %%
# %%time
# specify show_output to True for a verbose log
run.wait_for_completion(show_output=True)
# Out:
# RunId: experiment-1-adult-LightGBM_1605906446_89132a01
# Web View: https://ml.azure.com/experiments/experiment-1-adult-LightGBM/runs/experiment-1-adult-LightGBM_1605906446_89132a01?wsid=/subscriptions/79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5/resourcegroups/unive-resource-group/workspaces/unive-workspace
#
# Execution Summary
# =================
# RunId: experiment-1-adult-LightGBM_1605906446_89132a01
# Web View: https://ml.azure.com/experiments/experiment-1-adult-LightGBM/runs/experiment-1-adult-LightGBM_1605906446_89132a01?wsid=/subscriptions/79dab02c-2ae9-417c-ab9d-ca9bdf3a29c5/resourcegroups/unive-resource-group/workspaces/unive-workspace
#
# CPU times: user 28.4 ms, sys: 7.58 ms, total: 36 ms
# Wall time: 439 ms
# {'runId': 'experiment-1-adult-LightGBM_1605906446_89132a01',
#  'target': 'cpu-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2020-11-20T21:12:05.629327Z',
#  'endTimeUtc': '2020-11-20T21:20:00.128132Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'ce878311-b431-40a2-971d-8ce41735ac01',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': '6f454f5d-2ce5-4119-b1a7-86927834e823'}, 'consumptionDetails': {'type': 'Reference'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'train_adult_LightGBM.py',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'cpu-cluster',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'environment': {'name': 'adults-env',
#    'version': '1',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['anaconda', 'conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-sdk~=1.18.0',
#         'argparse',
#         'pyarrow',
#         'mlxtend',
#         'watermark']},
#       'pandas',
#       'numpy',
#       'scikit-learn',
#       'joblib',
#       'ipykernel',
#       'matplotlib',
#       'lightgbm'],
#      'name': 'azureml_41c75231e8a7b52fe1c9876e32427ac6'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'frameworkImage': None,
#    'imageVersion': None,
#    'location': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_276530b773ac0de02faff403a34b8bc1f5c46c4bef5c5ec38d94fd59122ea4fd_d.txt': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/azureml-logs/55_azureml-execution-tvmps_276530b773ac0de02faff403a34b8bc1f5c46c4bef5c5ec38d94fd59122ea4fd_d.txt?sv=2019-02-02&sr=b&sig=rU4RABkNUe2bGHOuUE%2FGnnHgjvsSzHBXbx%2BCmfLn54Y%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_276530b773ac0de02faff403a34b8bc1f5c46c4bef5c5ec38d94fd59122ea4fd_d.txt': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/azureml-logs/65_job_prep-tvmps_276530b773ac0de02faff403a34b8bc1f5c46c4bef5c5ec38d94fd59122ea4fd_d.txt?sv=2019-02-02&sr=b&sig=GnDEM6IX9VKM8ON6%2Ba%2BHQ6fZPUdNgMbOwWW3MT7FqgI%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=BLVUZrS71GbeHeyeyBqC443zrqS31vl5UapaL%2FPQah8%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_276530b773ac0de02faff403a34b8bc1f5c46c4bef5c5ec38d94fd59122ea4fd_d.txt': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/azureml-logs/75_job_post-tvmps_276530b773ac0de02faff403a34b8bc1f5c46c4bef5c5ec38d94fd59122ea4fd_d.txt?sv=2019-02-02&sr=b&sig=GstgX2W8vIny7pgExER3hBw2p3nMFBu2WkyYwEja78g%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'azureml-logs/process_info.json': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=bEukib%2Bdy2F3YsxvrDvHCoIR6NO2g07tQvcCVEyhaAU%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'azureml-logs/process_status.json': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=2HgwonW9buDi79jMpga5cCeIDkxJbsbf6T0iWhsR%2Bk4%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'logs/azureml/101_azureml.log': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/logs/azureml/101_azureml.log?sv=2019-02-02&sr=b&sig=wZLOUCXZDzc4Xdn3NdPXdghyUkRst8s3pf8rJaT2HZY%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/logs/azureml/dataprep/backgroundProcess.log?sv=2019-02-02&sr=b&sig=H0v9%2BmeaVKG1OSeDIzh4jSPQphhX7BmaXjkCsZYdkk4%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-02-02&sr=b&sig=Y9g0HAAnbsXZczKaHL%2B4%2FLkkSzfzTcAxjJ86kU%2Fk3aQ%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'logs/azureml/dataprep/engine_spans_9b1b3511-0c4d-41cb-88bb-cbcd65cf9a51.jsonl': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/logs/azureml/dataprep/engine_spans_9b1b3511-0c4d-41cb-88bb-cbcd65cf9a51.jsonl?sv=2019-02-02&sr=b&sig=u%2FijtZHy63rk64pDxA5L%2FH7UcumO7rKnYV3PJA%2B7dcc%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'logs/azureml/dataprep/python_span_9b1b3511-0c4d-41cb-88bb-cbcd65cf9a51.jsonl': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/logs/azureml/dataprep/python_span_9b1b3511-0c4d-41cb-88bb-cbcd65cf9a51.jsonl?sv=2019-02-02&sr=b&sig=vgrS2g%2BfewAN1xnKFeb7pvKvOXE3NFqe55GjY4uwdTY%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=MOkhi8%2F1BqqEy0wJTIQEUWzSa2i2g2VmbrU9Aw4XmkQ%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://univeworstoraged97f3a4a3.blob.core.windows.net/azureml/ExperimentRun/dcid.experiment-1-adult-LightGBM_1605906446_89132a01/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=UscqfX5t5cBa5SByfngLar42oEPRDaQDJZBc1d6pwN8%3D&st=2020-11-20T21%3A10%3A54Z&se=2020-11-21T05%3A20%3A54Z&sp=r'}}

# %% [markdown]
# 3. Register the Model
#
# Registers the output pickle file in the Azure ML service workspace. Once this code completes, a Model will show up in the Azure portal.

# %%
# register model 
model = run.register_model(model_name='model-adult', model_path='outputs/adult_transformed_LightGBM.pkl')
print(model.name, model.id, model.version, sep='\t')
# Out:
# model-adult	model-adult:2	2

# %% [markdown]
# 4. Download the model

# %%
# download model
import os 
from azureml.core import Workspace
from azureml.core.model import Model

ws = Workspace.from_config()
model=Model(ws, 'model-adult')
model.download(target_dir=os.path.join(os.getcwd(), "model"), exist_ok=True)

# verify the downloaded model file
file_path = os.path.join(os.getcwd(), "model/adult_transformed_LightGBM.pkl")
print(f"file path: {file_path}")
os.stat(file_path)
# Out:
# file path: /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-standardds1-v2/code/Users/877159/model/adult_transformed_LightGBM.pkl
# os.stat_result(st_mode=33279, st_ino=16140973632263290880, st_dev=45, st_nlink=1, st_uid=0, st_gid=0, st_size=223041, st_atime=1605907592, st_mtime=1605907592, st_ctime=1605907592)

# %%
from IPython.display import Image

Image(filename='images/Azure/Exp-2/lightGBM-2/conf_mat.png')

# %% [markdown]
# #### Transformed (Designer)

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/metrics-designer.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/metrics.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/driver_log.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/Model-download.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/dataset.png')

# %% [markdown]
# ### Analysis Result

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/metrics-designer-comparison.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/visualize.png')

# %% [markdown]
# ## Designer module Parameters

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/0-pipeline.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/1-dataset.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/2-split.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/2-classifier.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/3-trainmodel.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/4-scoremodel.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/5-evaluatemodel.png')

# %%
Image(filename='images/Azure/Exp-2/lightGBM-2/5-evaluatemodel-2.png')
